# %%
spark.sql(""" USE CATALOG ev_spark""")

# %%
# %sql
select current_catalog()

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS ev_spark.bronze;
CREATE SCHEMA IF NOT EXISTS ev_spark.silver;
CREATE SCHEMA IF NOT EXISTS ev_spark.gold;

# %%
# %sql
